# %%
import pandas as np
import numpy as np
import matplotlib.pyplot as plt

# %%
salaries_data=pd.read_excel(r"C:\Users\user\Desktop\DO NOT DELETE\DATA SCIENCE\Book1.xlsx")
salaries_data
# Out:
#      number  work_year EXPERTperiEntry-levelce_level employment_type  \
# 0         0       2020                     Mid level        FullTime
# 1         1       2020                        Senior        FullTime
# 2         2       2020                        Senior        FullTime
# 3         3       2020                     Mid level        FullTime
# 4         4       2020                        Senior        FullTime
# ..      ...        ...                           ...             ...
# 602     602       2022                        Senior        FullTime
# 603     603       2022                        Senior        FullTime
# 604     604       2022                        Senior        FullTime
# 605     605       2022                        Senior        FullTime
# 606     606       2022                     Mid level        FullTime
#
#                       job_title  salary salary_currency  salary_in_usd  \
# ...

# %%
salaries_data.isnull().count()
# Out:
# number                           607
# work_year                        607
# EXPERTperiEntry-levelce_level    607
# employment_type                  607
# job_title                        607
# salary                           607
# salary_currency                  607
# salary_in_usd                    607
# employee_residence               607
# remote_ratio                     607
# company_location                 607
# company size                     607
# dtype: int64

# %%
salaries_data.columns
# Out:
# Index(['number', 'work_year', 'EXPERTperiEntry-levelce_level',
#        'employment_type', 'job_title', 'salary', 'salary_currency',
#        'salary_in_usd', 'employee_residence', 'remote_ratio',
#        'company_location', 'company size'],
#       dtype='object')

# %%
salaries_data.dtypes
# Out:
# number                            int64
# work_year                         int64
# EXPERTperiEntry-levelce_level    object
# employment_type                  object
# job_title                        object
# salary                            int64
# salary_currency                  object
# salary_in_usd                     int64
# employee_residence               object
# remote_ratio                      int64
# company_location                 object
# company size                     object
# dtype: object

# %%
salaries_data.drop(columns='number',inplace=True)

# %%
salaries_data
# Out:
#      work_year EXPERTperiEntry-levelce_level employment_type  \
# 0         2020                     Mid level        FullTime
# 1         2020                        Senior        FullTime
# 2         2020                        Senior        FullTime
# 3         2020                     Mid level        FullTime
# 4         2020                        Senior        FullTime
# ..         ...                           ...             ...
# 602       2022                        Senior        FullTime
# 603       2022                        Senior        FullTime
# 604       2022                        Senior        FullTime
# 605       2022                        Senior        FullTime
# 606       2022                     Mid level        FullTime
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
salaries_data.rename(columns={'EXPERTperiEntry-levelce_level':'Experience level'},inplace=True)

# %%
salaries_data
# Out:
#      work_year Exprience level employment_type                   job_title  \
# 0         2020       Mid level        FullTime              Data Scientist
# 1         2020          Senior        FullTime  Machine Learning Scientist
# 2         2020          Senior        FullTime           Big Data Engineer
# 3         2020       Mid level        FullTime        Product Data Analyst
# 4         2020          Senior        FullTime   Machine Learning Engineer
# ..         ...             ...             ...                         ...
# 602       2022          Senior        FullTime               Data Engineer
# 603       2022          Senior        FullTime               Data Engineer
# 604       2022          Senior        FullTime                Data Analyst
# 605       2022          Senior        FullTime                Data Analyst
# 606       2022       Mid level        FullTime                AI Scientist
#
# ...

# %%
new=salaries_data.groupby('Exprience level')['salary_in_usd'].mean()
new
# Out:
# Exprience level
# EXPERT         199392.038462
# Entry-level     61643.318182
# Mid level       87996.056338
# Senior         138617.292857
# Name: salary_in_usd, dtype: float64

# %%
new.plot(kind='bar',color='pink')
plt.title('Salaries per exprience level')
# Out:
# Text(0.5, 1.0, 'Salaries per exprience level')

# %%
job=salaries_data.groupby('job_title')['salary_in_usd'].mean()
job
# Out:
# job_title
# 3D Computer Vision Researcher                 5409.000000
# AI Scientist                                 66135.571429
# Analytics Engineer                          175000.000000
# Applied Data Scientist                      175655.000000
# Applied Machine Learning Scientist          142068.750000
# BI Data Analyst                              74755.166667
# Big Data Architect                           99703.000000
# Big Data Engineer                            51974.000000
# Business Data Analyst                        76691.200000
# Cloud Data Engineer                         124647.000000
# Computer Vision Engineer                     44419.333333
# Computer Vision Software Engineer           105248.666667
# Data Analyst                                 92893.061856
# Data Analytics Engineer                      64799.250000
# Data Analytics Lead                         405000.000000
# Data Analytics Manager                      127134.285714
# ...

# %%
job.sort_values(ascending=False,inplace=True)

# %%
job[:10].plot(kind='barh')
plt.title('Top 10 average salaries')
# Out:
# Text(0.5, 1.0, 'Top 10 average salaries')

# %%
size=salaries_data.groupby('company size')['salary_in_usd'].mean()
size
# Out:
# company size
# Large     119242.994949
# Medium    116905.466258
# Small      77632.674699
# Name: salary_in_usd, dtype: float64

# %%
plt.pie(size,labels=[f'{i} company'for i in size.index])
plt.title('Salaries according to company size')
# Out:
# Text(0.5, 1.0, 'Salaries according to company size')

# %%
remote=salaries_data.groupby('remote_ratio')['salary_in_usd'].mean()
remote
# Out:
# remote_ratio
# 0      106354.622047
# 50      80823.030303
# 100    122457.454068
# Name: salary_in_usd, dtype: float64

# %%
plt.pie(remote,labels=[f'{i}%'for i in remote.index])
plt.title('Salaries per remote ratio')
# Out:
# Text(0.5, 1.0, 'Salaries per remote ratio')
